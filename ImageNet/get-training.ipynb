# %%
import shutil
import os

output_dir = "/kaggle/working/imagenet_subset"

if os.path.exists(output_dir):
    shutil.rmtree(output_dir)
    print("Old output directory removed.")

os.makedirs(output_dir, exist_ok=True)
print("New output directory created.")
# Out:
# New output directory created.

# %%
import os
import shutil

src_list = [
    "/kaggle/input/imagenet1k2",
    "/kaggle/input/imagenet1k0"
]

dst = "/kaggle/working/imagenet_subset"
os.makedirs(dst, exist_ok=True)

for src in src_list:
    print(f"Processing dataset: {src}")
    classes = sorted(os.listdir(src))[:100]  
    
    for cls in classes:
        src_path = os.path.join(src, cls)
        dst_path = os.path.join(dst, cls)

        
        if not os.path.exists(dst_path):
            print(f"Copying class {cls} from {src}")
            shutil.copytree(src_path, dst_path)

        
        else:
            print(f"Merging class {cls} from {src}")
            for fname in os.listdir(src_path):
                src_file = os.path.join(src_path, fname)
                dst_file = os.path.join(dst_path, fname)
                
                
                if not os.path.exists(dst_file):
                    shutil.copy2(src_file, dst_file)
# Out:
# Processing dataset: /kaggle/input/imagenet1k2
# Copying class 00000 from /kaggle/input/imagenet1k2
# Copying class 00001 from /kaggle/input/imagenet1k2
# Copying class 00002 from /kaggle/input/imagenet1k2
# Copying class 00003 from /kaggle/input/imagenet1k2
# Copying class 00004 from /kaggle/input/imagenet1k2
# Copying class 00005 from /kaggle/input/imagenet1k2
# Copying class 00006 from /kaggle/input/imagenet1k2
# Copying class 00007 from /kaggle/input/imagenet1k2
# Copying class 00008 from /kaggle/input/imagenet1k2
# Copying class 00009 from /kaggle/input/imagenet1k2
# Copying class 00010 from /kaggle/input/imagenet1k2
# Copying class 00011 from /kaggle/input/imagenet1k2
# Copying class 00012 from /kaggle/input/imagenet1k2
# Copying class 00013 from /kaggle/input/imagenet1k2
# Copying class 00014 from /kaggle/input/imagenet1k2
# Copying class 00015 from /kaggle/input/imagenet1k2
# Copying class 00016 from /kaggle/input/imagenet1k2
# Copying class 00017 from /kaggle/input/imagenet1k2
# Copying class 00018 from /kaggle/input/imagenet1k2
# Copying class 00019 from /kaggle/input/imagenet1k2
# Copying class 00020 from /kaggle/input/imagenet1k2
# Copying class 00021 from /kaggle/input/imagenet1k2
# Copying class 00022 from /kaggle/input/imagenet1k2
# Copying class 00023 from /kaggle/input/imagenet1k2
# Copying class 00024 from /kaggle/input/imagenet1k2
# Copying class 00025 from /kaggle/input/imagenet1k2
# Copying class 00026 from /kaggle/input/imagenet1k2
# Copying class 00027 from /kaggle/input/imagenet1k2
# Copying class 00028 from /kaggle/input/imagenet1k2
# Copying class 00029 from /kaggle/input/imagenet1k2
# Copying class 00030 from /kaggle/input/imagenet1k2
# Copying class 00031 from /kaggle/input/imagenet1k2
# Copying class 00032 from /kaggle/input/imagenet1k2
# Copying class 00033 from /kaggle/input/imagenet1k2
# Copying class 00034 from /kaggle/input/imagenet1k2
# Copying class 00035 from /kaggle/input/imagenet1k2
# Copying class 00036 from /kaggle/input/imagenet1k2
# Copying class 00037 from /kaggle/input/imagenet1k2
# Copying class 00038 from /kaggle/input/imagenet1k2
# Copying class 00039 from /kaggle/input/imagenet1k2
# Copying class 00040 from /kaggle/input/imagenet1k2
# Copying class 00041 from /kaggle/input/imagenet1k2
# Copying class 00042 from /kaggle/input/imagenet1k2
# Copying class 00043 from /kaggle/input/imagenet1k2
# Copying class 00044 from /kaggle/input/imagenet1k2
# Copying class 00045 from /kaggle/input/imagenet1k2
# Copying class 00046 from /kaggle/input/imagenet1k2
# Copying class 00047 from /kaggle/input/imagenet1k2
# Copying class 00048 from /kaggle/input/imagenet1k2
# Copying class 00049 from /kaggle/input/imagenet1k2
# Copying class 00050 from /kaggle/input/imagenet1k2
# Copying class 00051 from /kaggle/input/imagenet1k2
# Copying class 00052 from /kaggle/input/imagenet1k2
# Copying class 00053 from /kaggle/input/imagenet1k2
# Copying class 00054 from /kaggle/input/imagenet1k2
# Copying class 00055 from /kaggle/input/imagenet1k2
# Copying class 00056 from /kaggle/input/imagenet1k2
# Copying class 00057 from /kaggle/input/imagenet1k2
# Copying class 00058 from /kaggle/input/imagenet1k2
# Copying class 00059 from /kaggle/input/imagenet1k2
# Copying class 00060 from /kaggle/input/imagenet1k2
# Copying class 00061 from /kaggle/input/imagenet1k2
# Copying class 00062 from /kaggle/input/imagenet1k2
# Copying class 00063 from /kaggle/input/imagenet1k2
# Copying class 00064 from /kaggle/input/imagenet1k2
# Copying class 00065 from /kaggle/input/imagenet1k2
# Copying class 00066 from /kaggle/input/imagenet1k2
# Copying class 00067 from /kaggle/input/imagenet1k2
# Copying class 00068 from /kaggle/input/imagenet1k2
# Copying class 00069 from /kaggle/input/imagenet1k2
# Copying class 00070 from /kaggle/input/imagenet1k2
# Copying class 00071 from /kaggle/input/imagenet1k2
# Copying class 00072 from /kaggle/input/imagenet1k2
# Copying class 00073 from /kaggle/input/imagenet1k2
# Copying class 00074 from /kaggle/input/imagenet1k2
# Copying class 00075 from /kaggle/input/imagenet1k2
# Copying class 00076 from /kaggle/input/imagenet1k2
# Copying class 00077 from /kaggle/input/imagenet1k2
# Copying class 00078 from /kaggle/input/imagenet1k2
# Copying class 00079 from /kaggle/input/imagenet1k2
# Copying class 00080 from /kaggle/input/imagenet1k2
# Copying class 00081 from /kaggle/input/imagenet1k2
# Copying class 00082 from /kaggle/input/imagenet1k2
# Copying class 00083 from /kaggle/input/imagenet1k2
# Copying class 00084 from /kaggle/input/imagenet1k2
# Copying class 00085 from /kaggle/input/imagenet1k2
# Copying class 00086 from /kaggle/input/imagenet1k2
# Copying class 00087 from /kaggle/input/imagenet1k2
# Copying class 00088 from /kaggle/input/imagenet1k2
# Copying class 00089 from /kaggle/input/imagenet1k2
# Copying class 00090 from /kaggle/input/imagenet1k2
# Copying class 00091 from /kaggle/input/imagenet1k2
# Copying class 00092 from /kaggle/input/imagenet1k2
# Copying class 00093 from /kaggle/input/imagenet1k2
# Copying class 00094 from /kaggle/input/imagenet1k2
# Copying class 00095 from /kaggle/input/imagenet1k2
# Copying class 00096 from /kaggle/input/imagenet1k2
# Copying class 00097 from /kaggle/input/imagenet1k2
# Copying class 00098 from /kaggle/input/imagenet1k2
# Copying class 00099 from /kaggle/input/imagenet1k2
# Processing dataset: /kaggle/input/imagenet1k0
# Merging class 00000 from /kaggle/input/imagenet1k0
# Merging class 00001 from /kaggle/input/imagenet1k0
# Merging class 00002 from /kaggle/input/imagenet1k0
# Merging class 00003 from /kaggle/input/imagenet1k0
# Merging class 00004 from /kaggle/input/imagenet1k0
# Merging class 00005 from /kaggle/input/imagenet1k0
# Merging class 00006 from /kaggle/input/imagenet1k0
# Merging class 00007 from /kaggle/input/imagenet1k0
# Merging class 00008 from /kaggle/input/imagenet1k0
# Merging class 00009 from /kaggle/input/imagenet1k0
# Merging class 00010 from /kaggle/input/imagenet1k0
# Merging class 00011 from /kaggle/input/imagenet1k0
# Merging class 00012 from /kaggle/input/imagenet1k0
# Merging class 00013 from /kaggle/input/imagenet1k0
# Merging class 00014 from /kaggle/input/imagenet1k0
# Merging class 00015 from /kaggle/input/imagenet1k0
# Merging class 00016 from /kaggle/input/imagenet1k0
# Merging class 00017 from /kaggle/input/imagenet1k0
# Merging class 00018 from /kaggle/input/imagenet1k0
# Merging class 00019 from /kaggle/input/imagenet1k0
# Merging class 00020 from /kaggle/input/imagenet1k0
# Merging class 00021 from /kaggle/input/imagenet1k0
# Merging class 00022 from /kaggle/input/imagenet1k0
# Merging class 00023 from /kaggle/input/imagenet1k0
# Merging class 00024 from /kaggle/input/imagenet1k0
# Merging class 00025 from /kaggle/input/imagenet1k0
# Merging class 00026 from /kaggle/input/imagenet1k0
# Merging class 00027 from /kaggle/input/imagenet1k0
# Merging class 00028 from /kaggle/input/imagenet1k0
# Merging class 00029 from /kaggle/input/imagenet1k0
# Merging class 00030 from /kaggle/input/imagenet1k0
# Merging class 00031 from /kaggle/input/imagenet1k0
# Merging class 00032 from /kaggle/input/imagenet1k0
# Merging class 00033 from /kaggle/input/imagenet1k0
# Merging class 00034 from /kaggle/input/imagenet1k0
# Merging class 00035 from /kaggle/input/imagenet1k0
# Merging class 00036 from /kaggle/input/imagenet1k0
# Merging class 00037 from /kaggle/input/imagenet1k0
# Merging class 00038 from /kaggle/input/imagenet1k0
# Merging class 00039 from /kaggle/input/imagenet1k0
# Merging class 00040 from /kaggle/input/imagenet1k0
# Merging class 00041 from /kaggle/input/imagenet1k0
# Merging class 00042 from /kaggle/input/imagenet1k0
# Merging class 00043 from /kaggle/input/imagenet1k0
# Merging class 00044 from /kaggle/input/imagenet1k0
# Merging class 00045 from /kaggle/input/imagenet1k0
# Merging class 00046 from /kaggle/input/imagenet1k0
# Merging class 00047 from /kaggle/input/imagenet1k0
# Merging class 00048 from /kaggle/input/imagenet1k0
# Merging class 00049 from /kaggle/input/imagenet1k0
# Merging class 00050 from /kaggle/input/imagenet1k0
# Merging class 00051 from /kaggle/input/imagenet1k0
# Merging class 00052 from /kaggle/input/imagenet1k0
# Merging class 00053 from /kaggle/input/imagenet1k0
# Merging class 00054 from /kaggle/input/imagenet1k0
# Merging class 00055 from /kaggle/input/imagenet1k0
# Merging class 00056 from /kaggle/input/imagenet1k0
# Merging class 00057 from /kaggle/input/imagenet1k0
# Merging class 00058 from /kaggle/input/imagenet1k0
# Merging class 00059 from /kaggle/input/imagenet1k0
# Merging class 00060 from /kaggle/input/imagenet1k0
# Merging class 00061 from /kaggle/input/imagenet1k0
# Merging class 00062 from /kaggle/input/imagenet1k0
# Merging class 00063 from /kaggle/input/imagenet1k0
# Merging class 00064 from /kaggle/input/imagenet1k0
# Merging class 00065 from /kaggle/input/imagenet1k0
# Merging class 00066 from /kaggle/input/imagenet1k0
# Merging class 00067 from /kaggle/input/imagenet1k0
# Merging class 00068 from /kaggle/input/imagenet1k0
# Merging class 00069 from /kaggle/input/imagenet1k0
# Merging class 00070 from /kaggle/input/imagenet1k0
# Merging class 00071 from /kaggle/input/imagenet1k0
# Merging class 00072 from /kaggle/input/imagenet1k0
# Merging class 00073 from /kaggle/input/imagenet1k0
# Merging class 00074 from /kaggle/input/imagenet1k0
# Merging class 00075 from /kaggle/input/imagenet1k0
# Merging class 00076 from /kaggle/input/imagenet1k0
# Merging class 00077 from /kaggle/input/imagenet1k0
# Merging class 00078 from /kaggle/input/imagenet1k0
# Merging class 00079 from /kaggle/input/imagenet1k0
# Merging class 00080 from /kaggle/input/imagenet1k0
# Merging class 00081 from /kaggle/input/imagenet1k0
# Merging class 00082 from /kaggle/input/imagenet1k0
# Merging class 00083 from /kaggle/input/imagenet1k0
# Merging class 00084 from /kaggle/input/imagenet1k0
# Merging class 00085 from /kaggle/input/imagenet1k0
# Merging class 00086 from /kaggle/input/imagenet1k0
# Merging class 00087 from /kaggle/input/imagenet1k0
# Merging class 00088 from /kaggle/input/imagenet1k0
# Merging class 00089 from /kaggle/input/imagenet1k0
# Merging class 00090 from /kaggle/input/imagenet1k0
# Merging class 00091 from /kaggle/input/imagenet1k0
# Merging class 00092 from /kaggle/input/imagenet1k0
# Merging class 00093 from /kaggle/input/imagenet1k0
# Merging class 00094 from /kaggle/input/imagenet1k0
# Merging class 00095 from /kaggle/input/imagenet1k0
# Merging class 00096 from /kaggle/input/imagenet1k0
# Merging class 00097 from /kaggle/input/imagenet1k0
# Merging class 00098 from /kaggle/input/imagenet1k0
# Merging class 00099 from /kaggle/input/imagenet1k0

# %%
# !zip -r imagenet_subset.zip imagenet_subset

# %%
import os
import zipfile

base = "/kaggle/working/imagenet_subset"
classes = sorted(os.listdir(base))
chunk_size = 30   

for idx in range(0, 100, chunk_size):
    chunk = classes[idx: idx + chunk_size]
    zip_name = f"imagenet_subset_part_{idx//chunk_size + 1}.zip"
    zip_path = os.path.join("/kaggle/working", zip_name)

    print("Creating", zip_name)

    with zipfile.ZipFile(zip_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for cls in chunk:
            cls_path = os.path.join(base, cls)
            for root, _, files in os.walk(cls_path):
                for f in files:
                    fpath = os.path.join(root, f)
                    arcname = os.path.relpath(fpath, base)
                    zipf.write(fpath, arcname)

print("All parts created!")
# Out:
# Creating imagenet_subset_part_1.zip
# Creating imagenet_subset_part_2.zip
# Creating imagenet_subset_part_3.zip
# Creating imagenet_subset_part_4.zip
# All parts created!
